# %% [markdown]
# # setup sweagent
# https://swe-agent.com/latest/installation/source/

# %%
# gpgで復号化
# !gpg --batch --yes --passphrase "1" -d /kaggle/input/cpython-3-11-11/cpython-3.11.11-linux-x86_64-gnu.tar.gz.gpg > cpython-3.11.11-linux-x86_64-gnu.tar.gz
# tar.gzを解凍
# !tar -zxvf cpython-3.11.11-linux-x86_64-gnu.tar.gz
#setup py311 env
# !uv venv my_env --python=root/.local/share/uv/python/cpython-3.11.11-linux-x86_64-gnu

# %%
# !mkdir /kaggle/working/sweagent
# !cp --recursive /kaggle/input/swe-agent-v1-0-1-sota-on-swe-bench-full/* /kaggle/working/sweagent

# !my_env/bin/python -m ensurepip
# !my_env/bin/python -V
# !my_env/bin/python -m pip --version

# !my_env/bin/python -m pip install /kaggle/input/pip-25-0-1-py3-none-any-whl/pip-25.0.1-py3-none-any.whl
#!my_env/bin/python -m pip install --no-index --find-links=/kaggle/input/packages-for-sweagent/packages -r /kaggle/input/konwinski-prize-requirements/requirements.txt
#!my_env/bin/python -m pip install -e /kaggle/working/sweagent/. --no-index --find-links=/kaggle/input/packages-for-sweagent/packages --find-links=/kaggle/input/setuptools-75-8-2/
# !my_env/bin/python -m pip install -e /kaggle/working/sweagent/. --no-index \
--find-links=/kaggle/input/setuptools-75-8-2/ \
--find-links=/kaggle/input/packages-for-sweagent/packages
# Out:
# Looking in links: /tmp/tmp_itf72lh
# Processing /tmp/tmp_itf72lh/setuptools-65.5.0-py3-none-any.whl
# Processing /tmp/tmp_itf72lh/pip-24.0-py3-none-any.whl
# Installing collected packages: setuptools, pip
# Successfully installed pip-24.0 setuptools-65.5.0
# Python 3.11.11
# pip 24.0 from /kaggle/working/my_env/lib/python3.11/site-packages/pip (python 3.11)
# Processing /kaggle/input/pip-25-0-1-py3-none-any-whl/pip-25.0.1-py3-none-any.whl
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-25.0.1
# Looking in links: /kaggle/input/setuptools-75-8-2/, /kaggle/input/packages-for-sweagent/packages
# Obtaining file:///kaggle/working/sweagent
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Processing /kaggle/input/packages-for-sweagent/packages/datasets-3.3.2-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/rich-13.9.4-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/ruamel.yaml-0.18.10-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tenacity-9.0.0-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/unidiff-0.7.5-py2.py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/simple_parsing-0.1.7-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/rich_argparse-1.7.0-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/flask-3.1.0-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/flask_cors-5.0.1-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/Flask_SocketIO-5.5.1-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pydantic-2.10.6-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/python_dotenv-1.0.1-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pydantic_settings-2.8.1-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/litellm-1.63.3-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/GitPython-3.1.44-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/ghapi-1.0.6-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/swe_rex-1.2.1-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tabulate-0.9.0-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/textual-1.0.0-py3-none-any.whl (from sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/fastapi-0.115.11-py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/uvicorn-0.34.0-py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/requests-2.32.3-py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pexpect-4.9.0-py2.py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/bashlex-0.18-py2.py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/python_multipart-0.0.20-py3-none-any.whl (from swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/annotated_types-0.7.0-py3-none-any.whl (from pydantic->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from pydantic->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/typing_extensions-4.12.2-py3-none-any.whl (from pydantic->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/markdown_it_py-3.0.0-py3-none-any.whl (from markdown-it-py[linkify,plugins]>=2.1.0->textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/platformdirs-4.3.6-py3-none-any.whl (from textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pygments-2.19.1-py3-none-any.whl (from rich->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/filelock-3.17.0-py3-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pyarrow-19.0.1-cp311-cp311-manylinux_2_28_x86_64.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/dill-0.3.8-py3-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tqdm-4.67.1-py3-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/multiprocess-0.70.16-py311-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/fsspec-2024.12.0-py3-none-any.whl (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/aiohttp-3.11.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/huggingface_hub-0.29.2-py3-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/packaging-24.2-py3-none-any.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/werkzeug-3.1.3-py3-none-any.whl (from flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/jinja2-3.1.6-py3-none-any.whl (from flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/itsdangerous-2.2.0-py3-none-any.whl (from flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/click-8.1.8-py3-none-any.whl (from flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/blinker-1.9.0-py3-none-any.whl (from flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/python_socketio-5.12.1-py3-none-any.whl (from flask-socketio->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/fastcore-1.7.29-py3-none-any.whl (from ghapi->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/gitdb-4.0.12-py3-none-any.whl (from GitPython->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/httpx-0.28.1-py3-none-any.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/importlib_metadata-8.6.1-py3-none-any.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/jsonschema-4.23.0-py3-none-any.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/openai-1.65.4-py3-none-any.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (from pandas->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/pytz-2025.1-py2.py3-none-any.whl (from pandas->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/tzdata-2025.1-py2.py3-none-any.whl (from pandas->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from ruamel.yaml->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/docstring_parser-0.16-py3-none-any.whl (from simple-parsing->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/aiohappyeyeballs-2.5.0-py3-none-any.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/aiosignal-1.3.2-py2.py3-none-any.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/attrs-25.1.0-py3-none-any.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/frozenlist-1.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/propcache-0.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/yarl-1.18.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from aiohttp->datasets->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/smmap-5.0.2-py3-none-any.whl (from gitdb<5,>=4.0.1->GitPython->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/anyio-4.8.0-py3-none-any.whl (from httpx>=0.23.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/certifi-2025.1.31-py3-none-any.whl (from httpx>=0.23.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/httpcore-1.0.7-py3-none-any.whl (from httpx>=0.23.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/idna-3.10-py3-none-any.whl (from httpx>=0.23.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/h11-0.14.0-py3-none-any.whl (from httpcore==1.*->httpx>=0.23.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/zipp-3.21.0-py3-none-any.whl (from importlib-metadata>=6.8.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from Jinja2>=3.1.2->flask->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/jsonschema_specifications-2024.10.1-py3-none-any.whl (from jsonschema<5.0.0,>=4.22.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/referencing-0.36.2-py3-none-any.whl (from jsonschema<5.0.0,>=4.22.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/rpds_py-0.23.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from jsonschema<5.0.0,>=4.22.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/mdurl-0.1.2-py3-none-any.whl (from markdown-it-py>=2.1.0->markdown-it-py[linkify,plugins]>=2.1.0->textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/linkify_it_py-2.0.3-py3-none-any.whl (from markdown-it-py[linkify,plugins]>=2.1.0->textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/mdit_py_plugins-0.4.2-py3-none-any.whl (from markdown-it-py[linkify,plugins]>=2.1.0->textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/distro-1.9.0-py3-none-any.whl (from openai>=1.61.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/jiter-0.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from openai>=1.61.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/sniffio-1.3.1-py3-none-any.whl (from openai>=1.61.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/six-1.17.0-py2.py3-none-any.whl (from python-dateutil>=2.8.2->pandas->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/bidict-0.23.1-py3-none-any.whl (from python-socketio>=5.12.0->flask-socketio->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/python_engineio-4.11.2-py3-none-any.whl (from python-socketio>=5.12.0->flask-socketio->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from requests->swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/urllib3-2.3.0-py3-none-any.whl (from requests->swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from tiktoken>=0.7.0->litellm->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/starlette-0.46.1-py3-none-any.whl (from fastapi->swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/ptyprocess-0.7.0-py2.py3-none-any.whl (from pexpect->swe-rex>=1.2.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/uc_micro_py-1.0.3-py3-none-any.whl (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual<2.0.0,>=1.0.0->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/simple_websocket-1.1.0-py3-none-any.whl (from python-engineio>=4.11.0->python-socketio>=5.12.0->flask-socketio->sweagent==1.0.1)
# Processing /kaggle/input/packages-for-sweagent/packages/wsproto-1.2.0-py3-none-any.whl (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio>=5.12.0->flask-socketio->sweagent==1.0.1)
# Building wheels for collected packages: sweagent
#   Building editable for sweagent (pyproject.toml) ... done
#   Created wheel for sweagent: filename=sweagent-1.0.1-0.editable-py3-none-any.whl size=7588 sha256=e5718b6448f3f7dee4e564a9f5463f84f68bd9d41152a78ac4f712ada160e925
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5976k8_x/wheels/6b/f3/68/1b73d2c9463ebb6e9700877ba0d6152b920561bcee5dbb60cb
# Successfully built sweagent
# Installing collected packages: unidiff, pytz, ptyprocess, zipp, xxhash, urllib3, uc-micro-py, tzdata, typing-extensions, tqdm, tenacity, tabulate, sniffio, smmap, six, ruamel.yaml.clib, rpds-py, regex, pyyaml, python-multipart, python-dotenv, pygments, pyarrow, propcache, platformdirs, pexpect, packaging, numpy, multidict, mdurl, MarkupSafe, jiter, itsdangerous, idna, h11, fsspec, frozenlist, filelock, docstring-parser, distro, dill, click, charset-normalizer, certifi, blinker, bidict, bashlex, attrs, annotated-types, aiohappyeyeballs, yarl, wsproto, Werkzeug, uvicorn, simple-parsing, ruamel.yaml, requests, referencing, python-dateutil, pydantic-core, multiprocess, markdown-it-py, linkify-it-py, Jinja2, importlib-metadata, httpcore, gitdb, fastcore, anyio, aiosignal, tiktoken, starlette, simple-websocket, rich, pydantic, pandas, mdit-py-plugins, jsonschema-specifications, huggingface-hub, httpx, GitPython, ghapi, flask, aiohttp, tokenizers, rich-argparse, python-engineio, pydantic_settings, openai, jsonschema, flask-cors, fastapi, textual, swe-rex, python-socketio, litellm, datasets, flask-socketio, sweagent
# Successfully installed GitPython-3.1.44 Jinja2-3.1.6 MarkupSafe-3.0.2 Werkzeug-3.1.3 aiohappyeyeballs-2.5.0 aiohttp-3.11.13 aiosignal-1.3.2 annotated-types-0.7.0 anyio-4.8.0 attrs-25.1.0 bashlex-0.18 bidict-0.23.1 blinker-1.9.0 certifi-2025.1.31 charset-normalizer-3.4.1 click-8.1.8 datasets-3.3.2 dill-0.3.8 distro-1.9.0 docstring-parser-0.16 fastapi-0.115.11 fastcore-1.7.29 filelock-3.17.0 flask-3.1.0 flask-cors-5.0.1 flask-socketio-5.5.1 frozenlist-1.5.0 fsspec-2024.12.0 ghapi-1.0.6 gitdb-4.0.12 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.29.2 idna-3.10 importlib-metadata-8.6.1 itsdangerous-2.2.0 jiter-0.8.2 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 linkify-it-py-2.0.3 litellm-1.63.3 markdown-it-py-3.0.0 mdit-py-plugins-0.4.2 mdurl-0.1.2 multidict-6.1.0 multiprocess-0.70.16 numpy-2.2.3 openai-1.65.4 packaging-24.2 pandas-2.2.3 pexpect-4.9.0 platformdirs-4.3.6 propcache-0.3.0 ptyprocess-0.7.0 pyarrow-19.0.1 pydantic-2.10.6 pydantic-core-2.27.2 pydantic_settings-2.8.1 pygments-2.19.1 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 python-engineio-4.11.2 python-multipart-0.0.20 python-socketio-5.12.1 pytz-2025.1 pyyaml-6.0.2 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 rich-13.9.4 rich-argparse-1.7.0 rpds-py-0.23.1 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 simple-parsing-0.1.7 simple-websocket-1.1.0 six-1.17.0 smmap-5.0.2 sniffio-1.3.1 starlette-0.46.1 swe-rex-1.2.1 sweagent-1.0.1 tabulate-0.9.0 tenacity-9.0.0 textual-1.0.0 tiktoken-0.9.0 tokenizers-0.21.0 tqdm-4.67.1 typing-extensions-4.12.2 tzdata-2025.1 uc-micro-py-1.0.3 unidiff-0.7.5 urllib3-2.3.0 uvicorn-0.34.0 wsproto-1.2.0 xxhash-3.5.0 yarl-1.18.3 zipp-3.21.0

# %%
# !my_env/bin/sweagent run -h
# Out:
# 👋 INFO     This is SWE-agent version 1.0.1 (hash='unavailable') with SWE-ReX version 1.2.1
#             (rex_hash='unavailable').
# Run SWE-agent on a single instance taken from github or similar.
#
# === BASIC OPTIONS ===
#
#   -h --help           Show help text and exit
#   --help_option      Print specific help text and exit
#   --config CONFIG     Load additional config files. Use this option multiple times to load
#                       multiple files, e.g., --config config1.yaml --config config2.yaml
#
# === EXAMPLES ===
#
# Basic usage: Run over a github issue:
#
# sweagent run --config config/default.yaml --agent.model.name "gpt-4o" \
#     --env.repo.github_url=https://github.com/SWE-agent/test-repo/ \
#     --problem_statement.github_url=https://github.com/SWE-agent/test-repo/issues/1
#
#
# By default this will start a docker container and run the agent in there.
# You can set the image with --env.docker.image.
#
# Here's an example that uses modal instead of docker and also a local repository:
#
# sweagent run --config config/default.yaml --agent.model.name "gpt-4o" \
#     --env.deployment.type=modal --env.repo.path /path/to/repo \
#     --problem_statement.path=path/to/problem_statement.md
#
#
# === ALL THE OPTIONS ===
#
# env: EnvironmentConfig
#     Environment options.
#     Run --help_option sweagent.environment.swe_env.EnvironmentConfig for more info
#
# agent: Agent options.
#     This config item can be one of the following things (run --help_option <name> for more info):
#     sweagent.agent.agents.DefaultAgentConfig
#     sweagent.agent.agents.RetryAgentConfig
#
# problem_statement: Problem statement options.
#     This config item can be one of the following things (run --help_option <name> for more info):
#     sweagent.agent.problem_statement.TextProblemStatement
#     sweagent.agent.problem_statement.GithubIssue
#     sweagent.agent.problem_statement.EmptyProblemStatement
#     sweagent.agent.problem_statement.FileProblemStatement
#
# output_dir: Path
#
# actions: RunSingleActionConfig
#     Run --help_option sweagent.run.run_single.RunSingleActionConfig for more info
#
# env_var_path: This config item can be one of the following things (run --help_option <name> for more
# info):
#     pathlib.Path
#     None

# %% [markdown]
# # ollama server
# https://stackoverflow.com/questions/78394289/running-ollama-on-kaggle

# %%
# !sudo tar -C /usr -xzf /kaggle/input/ollama-linux-amd64-tgz/ollama-linux-amd64.tgz

# %%
# !ollama -v
# Out:
# Warning: could not connect to a running Ollama instance
# Warning: client version is 0.5.13

# %%
# !mkdir -p /root/.ollama/models
# !cp -r /kaggle/input/qwen2_5_coder_for_ollama/other/0.5b/1/* /root/.ollama/models/
# !ls /root/.ollama/models/
# Out:
# blobs  manifests

# %%
import subprocess
process = subprocess.Popen("ollama serve", shell=True) #runs on a different thread

# %%
# !ollama list
# Out:
# NAME                  ID              SIZE      MODIFIED
# qwen2.5-coder:0.5b    d392ed348d5b    531 MB    6 seconds ago

# %% [markdown]
# # excute swe agent

# %%
# !my_env/bin/sweagent run --help
# Out:
# 👋 INFO     This is SWE-agent version 1.0.1 (hash='unavailable') with SWE-ReX version 1.2.1
#             (rex_hash='unavailable').
# Run SWE-agent on a single instance taken from github or similar.
#
# === BASIC OPTIONS ===
#
#   -h --help           Show help text and exit
#   --help_option      Print specific help text and exit
#   --config CONFIG     Load additional config files. Use this option multiple times to load
#                       multiple files, e.g., --config config1.yaml --config config2.yaml
#
# === EXAMPLES ===
#
# Basic usage: Run over a github issue:
#
# sweagent run --config config/default.yaml --agent.model.name "gpt-4o" \
#     --env.repo.github_url=https://github.com/SWE-agent/test-repo/ \
#     --problem_statement.github_url=https://github.com/SWE-agent/test-repo/issues/1
#
#
# By default this will start a docker container and run the agent in there.
# You can set the image with --env.docker.image.
#
# Here's an example that uses modal instead of docker and also a local repository:
#
# sweagent run --config config/default.yaml --agent.model.name "gpt-4o" \
#     --env.deployment.type=modal --env.repo.path /path/to/repo \
#     --problem_statement.path=path/to/problem_statement.md
#
#
# === ALL THE OPTIONS ===
#
# env: EnvironmentConfig
#     Environment options.
#     Run --help_option sweagent.environment.swe_env.EnvironmentConfig for more info
#
# agent: Agent options.
#     This config item can be one of the following things (run --help_option <name> for more info):
#     sweagent.agent.agents.DefaultAgentConfig
#     sweagent.agent.agents.RetryAgentConfig
#
# problem_statement: Problem statement options.
#     This config item can be one of the following things (run --help_option <name> for more info):
#     sweagent.agent.problem_statement.TextProblemStatement
#     sweagent.agent.problem_statement.GithubIssue
#     sweagent.agent.problem_statement.EmptyProblemStatement
#     sweagent.agent.problem_statement.FileProblemStatement
#
# output_dir: Path
#
# actions: RunSingleActionConfig
#     Run --help_option sweagent.run.run_single.RunSingleActionConfig for more info
#
# env_var_path: This config item can be one of the following things (run --help_option <name> for more
# info):
#     pathlib.Path
#     None

# %%
# !my_env/bin/sweagent run \
    --config /kaggle/working/sweagent/config/default.yaml\
    --agent.model.name=ollama/qwen2.5-coder:0.5b \
    --agent.model.api_base=http://localhost:11434 \
    --problem_statement.text="Hey, can you fix all the bugs?"

# %% [markdown]
# # demo

# %%
import io
import os
import shutil
import subprocess

import pandas as pd
import polars as pl

import kaggle_evaluation.konwinski_prize_inference_server

# %% [markdown]
# The evaluation API requires that you set up a server which will respond to inference requests. We have already defined the server; you just need write the predict function. When we evaluate your submission on the hidden test set the client defined in `konwinski_prize_gateway` will run in a different container with direct access to the hidden test set and hand off the data.
#
# Your code will always have access to the published copies of the files.

# %%
instance_count = None

def get_number_of_instances(num_instances: int) -> None:
    """ The very first message from the gateway will be the total number of instances to be served.
    You don't need to edit this function.
    """
    global instance_count
    instance_count = num_instances

# %%
first_prediction = True


def predict(problem_statement: str, repo_archive: io.BytesIO, pip_packages_archive: io.BytesIO, env_setup_cmds_templates: list[str]) -> str:
    """ Replace this function with your inference code.
    Args:
        problem_statement: The text of the git issue.
        repo_path: A BytesIO buffer path with a .tar containing the codebase that must be patched. The gateway will make this directory available immediately before this function runs.
        pip_packages_archive: A BytesIO buffer path with a .tar containing the wheel files necessary for running unit tests.
        env_setup_cmds_templates: Commands necessary for installing the pip_packages_archive.
    """
    global first_prediction
    if not first_prediction:
        return None  # Skip issue.

    # Unpack the codebase to be patched into a directory that won't be exported when
    # the notebook is saved.
    archive_path = '/tmp/repo_archive.tar'
    with open(archive_path, 'wb') as f:
        f.write(repo_archive.read())
    repo_path = 'repo'
    if os.path.exists(repo_path):
        shutil.rmtree(repo_path)
    shutil.unpack_archive(archive_path, extract_dir=repo_path)
    os.remove(archive_path)

    """
    Unpack pip_packages if you want to run unit tests on your patch.
    Note that editing unit tests with your patch -- even to add valid tests -- can cause your submission to be flagged as a failure.
    Most of the relevant repos use pytest for running tests. You will almost certainly need to run only a subset of the unit tests to avoid running out of inference time.
    """
    pip_archive_dir = '/tmp/pip_packages_archive.tar'
    with open(pip_archive_dir, 'wb') as f:
        f.write(pip_packages_archive.read())
    pip_packages_path = '/path/to/pip_packages'
    if os.path.exists(pip_packages_path):
        shutil.rmtree(pip_packages_path)
    shutil.unpack_archive(pip_archive_dir, extract_dir=pip_packages_path)
    os.remove(pip_archive_dir)

    # Get env setup cmds by setting the pip_packages_path
    env_setup_cmds = [cmd.format(pip_packages_path=pip_packages_path) for cmd in env_setup_cmds_templates]

    # Run env setup for the repo
    subprocess.run(
        "\n".join(env_setup_cmds),
        shell=True,
        executable="/bin/bash",
        cwd=repo_path,
    )

    first_prediction = False
    # Instead of a valid diff, let's just submit a generic string. This will definitely fail.

    
    
    return "Hello World"

# %% [markdown]
# When your notebook is run on the hidden test set, inference_server.serve must be called within 15 minutes of the notebook starting or the gateway will throw an error. If you need more than 15 minutes to load your model you can do so during the very first predict call, which does not have the usual 30 minute response deadline.

# %%
inference_server = kaggle_evaluation.konwinski_prize_inference_server.KPrizeInferenceServer(
    get_number_of_instances,   
    predict
)

if os.getenv('KAGGLE_IS_COMPETITION_RERUN'):
    inference_server.serve()
else:
    inference_server.run_local_gateway(
        data_paths=(
            '/kaggle/input/konwinski-prize/',  # Path to the entire competition dataset
            '/kaggle/tmp/konwinski-prize/',   # Path to a scratch directory for unpacking data.a_zip.
        ),
        use_concurrency=True,  # This can safely be disabled for purposes of local testing if necessary.
    )
